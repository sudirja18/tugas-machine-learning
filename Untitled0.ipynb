# %% [markdown]
# <a href="https://colab.research.google.com/github/sudirja18/tugas-machine-learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
path_="/content/drive/My Drive/covid_19_indonesia_time_series_all.csv"
dataset=pd.read_csv(path_)
dataset
# Out:
#             Date  ... Growth Factor of New Deaths
# 0       3/1/2020  ...                         NaN
# 1       3/2/2020  ...                         1.0
# 2       3/2/2020  ...                         NaN
# 3       3/2/2020  ...                         NaN
# 4       3/3/2020  ...                         1.0
# ...          ...  ...                         ...
# 7092  10/11/2020  ...                         NaN
# 7093  10/11/2020  ...                         1.0
# 7094  10/11/2020  ...                         0.6
# 7095  10/11/2020  ...                         0.0
# 7096  10/11/2020  ...                         NaN
#
# [7097 rows x 37 columns]

# %%
dataset.head()
# Out:
#        Date  ... Growth Factor of New Deaths
# 0  3/1/2020  ...                         NaN
# 1  3/2/2020  ...                         1.0
# 2  3/2/2020  ...                         NaN
# 3  3/2/2020  ...                         NaN
# 4  3/3/2020  ...                         1.0
#
# [5 rows x 37 columns]

# %%
dataset.shape
# Out:
# (7097, 37)

# %%
dataset.max()
# Out:
# Date                                 9/9/2020
# Location ISO Code                         IDN
# Location                       Sumatera Utara
# New Cases                                4850
# New Deaths                                160
# New Recovered                            4510
# New Active Cases                         1533
# Total Cases                            333449
# Total Deaths                            11844
# Total Recovered                        255027
# Total Active Cases                      66578
# Location Level                       Province
# City or Regency                           NaN
# Country                             Indonesia
# Continent                                Asia
# Total Regencies                           416
# Total Cities                               98
# Total Districts                          7230
# Total Urban Villages                     8488
# Total Rural Villages                    74953
# ...

# %%
dataset.min()
# Out:
# Date                           10/1/2020
# Location ISO Code                  ID-AC
# Location                            Aceh
# New Cases                              0
# New Deaths                             0
# New Recovered                          0
# New Active Cases                   -1762
# Total Cases                            1
# Total Deaths                           0
# Total Recovered                        0
# Total Active Cases                   -33
# Location Level                   Country
# City or Regency                      NaN
# Country                        Indonesia
# Continent                           Asia
# Total Regencies                        1
# Total Cities                           1
# Total Districts                       44
# Total Urban Villages                  35
# Total Rural Villages                 275
# Area (km2)                           664
# Population                        648407
# Population Density                  8.59
# ...

# %%
dataset.describe()
# Out:
#          New Cases  ...  Growth Factor of New Deaths
# count  7097.000000  ...                  6226.000000
# mean     93.874595  ...                     0.974846
# std     368.150061  ...                     0.963323
# min       0.000000  ...                     0.000000
# 25%       1.000000  ...                     1.000000
# 50%      10.000000  ...                     1.000000
# 75%      49.000000  ...                     1.000000
# max    4850.000000  ...                    27.000000
#
# [8 rows x 25 columns]

# %%
dataset.describe().loc['max','New Deaths']
# Out:
# 160.0

# %%
dataset.describe()['New Cases']['max']
# Out:
# 4850.0

# %%
data=dataset.dropna()

# %%
data.shape
# Out:
# (0, 37)

# %%
dataset.dropna(axis=0,subset=['New Cases','New Deaths'],inplace=True)

# %%
dataset.shape
# Out:
# (7097, 37)

# %%
#Memilih target prediksi(prediction target)
y=data['New Cases']
y
# Out:
# Series([], Name: New Cases, dtype: int64)

# %%
#Memilih fitur (feature selection)
fitur=['New Cases','Date']
X=data[fitur]
X
# Out:
# Empty DataFrame
# Columns: [New Cases, Date]
# Index: []
